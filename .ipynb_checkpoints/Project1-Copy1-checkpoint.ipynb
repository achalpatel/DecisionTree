# %%
import pandas as pd
import numpy as np
import json

# %%
myFile = pd.read_csv('D:/project/550_Pattern/Project_1/550-p1-cset-krk-1.csv')
myFile
myFrame=pd.DataFrame(myFile.values, columns = ["White-King-File", "White-King-rank", "White-Rook-file", "White-Rook-rank","Black-King-file","Black-King-rank","Class"])
myFrame
# Out:
#     White-King-File White-King-rank White-Rook-file White-Rook-rank  \
# 0                 c               1               e               2
# 1                 b               1               d               7
# 2                 d               2               g               1
# 3                 d               4               g               6
# 4                 c               1               b               5
# ..              ...             ...             ...             ...
# 214               d               3               d               7
# 215               b               1               b               4
# 216               d               4               e               8
# 217               c               2               d               5
# 218               d               4               c               6
#
#     Black-King-file Black-King-rank Class
# 0                 d               3  draw
# 1                 c               7  draw
# 2                 g               2  draw
# 3                 f               6  draw
# 4                 a               5  draw
# ..              ...             ...   ...
# 214               a               7  nine
# 215               g               1  nine
# 216               g               2  nine
# 217               f               1  nine
# 218               e               1  nine
#
# [219 rows x 7 columns]

# %%
myFrame.shape
# Out:
# (219, 7)

# %%
# Split into training set:60%, holdout set:20%, Validation set: 20%

training_set = myFrame.sample(frac=0.6)
remaining_set = myFrame.drop(training_set.index)
training_set
# Out:
#     White-King-File White-King-rank White-Rook-file White-Rook-rank  \
# 165               d               3               g               4
# 112               d               2               d               8
# 218               d               4               c               6
# 180               c               2               c               5
# 83                c               3               c               7
# ..              ...             ...             ...             ...
# 67                c               1               h               7
# 192               d               4               b               1
# 127               d               3               b               1
# 85                d               2               b               5
# 59                c               1               h               1
#
#     Black-King-file Black-King-rank  Class
# 165               h               6  seven
# 112               a               2   five
# 218               e               1   nine
# 180               b               8  eight
# 83                b               1  three
# ..              ...             ...    ...
# 67                a               1    two
# 192               h               2  eight
# 127               a               6   five
# 85                a               1  three
# 59                a               1    two
#
# [131 rows x 7 columns]

# %%
remaining_set
# Out:
#     White-King-File White-King-rank White-Rook-file White-Rook-rank  \
# 0                 c               1               e               2
# 3                 d               4               g               6
# 13                a               1               h               4
# 14                c               2               h               3
# 17                c               1               g               6
# ..              ...             ...             ...             ...
# 202               d               3               h               1
# 206               d               4               f               8
# 208               b               2               f               3
# 209               d               4               b               6
# 212               c               3               c               7
#
#     Black-King-file Black-King-rank Class
# 0                 d               3  draw
# 3                 f               6  draw
# 13                g               4  draw
# 14                g               3  draw
# 17                f               5  draw
# ..              ...             ...   ...
# 202               f               1  nine
# 206               g               6  nine
# 208               h               1  nine
# 209               e               1  nine
# 212               h               2  nine
#
# [88 rows x 7 columns]

# %%
classes, cls_counts = np.unique(training_set['Class'], return_counts = True)
classes, cls_counts
# Out:
# (array(['draw', 'eight', 'five', 'four', 'nine', 'one', 'seven', 'six',
#         'three', 'two', 'zero'], dtype=object),
#  array([14, 16, 11, 11, 15, 10, 13, 14, 12, 10,  5]))

# %%
def calculate_entropy(df_label):
    classes,class_counts = np.unique(df_label,return_counts = True)
    entropy_value = np.sum([(-class_counts[i]/np.sum(class_counts))*np.log2(class_counts[i]/np.sum(class_counts)) 
                        for i in range(len(classes))])
    return entropy_value

# %%
calculate_entropy(training_set['Class'])
# Out:
# 3.41135993987002

# %%
for cols in training_set.columns[:-1]:
    print(cols)
# Out:
# White-King-File
# White-King-rank
# White-Rook-file
# White-Rook-rank
# Black-King-file
# Black-King-rank

# %%
# dataset = training_set
# feature = Feature or attribute of the dataset, i.e column name (training_set.columns[:-1]) E.g White-King-File
# label = Name of Class label colums, i.e. 'Class'

def calculate_information_gain(dataset,feature,label): 
    # Calculate the dataset entropy
    dataset_entropy = calculate_entropy(dataset[label])   
    values,feat_counts= np.unique(dataset[feature],return_counts=True)
    
    # Calculate the weighted feature entropy                                # Call the calculate_entropy function
    weighted_feature_entropy = np.sum([(feat_counts[i]/np.sum(feat_counts))*calculate_entropy(dataset.where(dataset[feature]
                              ==values[i]).dropna()[label]) for i in range(len(values))])    
    feature_info_gain = dataset_entropy - weighted_feature_entropy    
    return feature_info_gain

# %%
calculate_information_gain(training_set, 'White-King-File', 'Class')
# Out:
# 0.49742389742141757

# %%
class DNode:
    def __init__(self, attribute):
        self.attribute = attribute
        self.values = []
        self.children = {}

# %%
class LeafNode:
    def __init__(self,value):
        self.value = value

# %%
attributes = training_set.columns[:-1]

# %%
def select_attribute(dataset, attributes):
    label = 'Class'
    
    gains = [calculate_information_gain(dataset, attribute, label) for attribute in attributes]
    print("gains",gains)
    maxGainIndex = np.argmax(gains)
    print("maxGainIndex",maxGainIndex)
    print("highGainAttribute:",attributes[maxGainIndex])

# %%
select_attribute(training_set, attributes)
# Out:
# gains [0.49742389742141757, 0.33558729586215197, 0.5178150834260635, 0.5000926294391945, 0.7451682333457743, 0.4987731004886613]
# maxGainIndex 4
# highGainAttribute: Black-King-file
